# %%
from IPython.display import Image

# %%
#Most common situation of sigma unknow which is population deviation

# %% [markdown]
# ### Standard error=(sigma)/Squrt(No of samples)
# sigma=Devation of overall population
#
# If we take larger sample it will be likely to be representaive of population.
# Increasing the sample size will reduce the standard error.
# But only until a certain point after that it becomes flat

# %%
Image('./Images/SGU1.png')

# %%
Image('./Images/SGU2.png')

# %% [markdown]
# ### T Distribution if no of samples <30

# %%
When we dont know the sigma we need to rely on students t distribution
we can assign t scores to upper and lower boundary of the 95%
interval for each sample size.

# %%
Image('./Images/SGU3.png')

# %%
Image('./Images/SGU4.png')

# %%
we know that z=1.96 for confidence interval of 95%
but just check below for how we will calculate the t values which
play a very important role in finding the confidence intervals
as the sigma which is devation of population is unknown

# %%
We find the t values using the t-distribution table 
which is available in every stat book
How we gonna check is below step by step

# %%
Image('./Images/SGU5.png')

# %% [markdown]
# ### STEP 1:
#     Check the interval of small tails which is   0.25 as shown in figure above.
#     As Marked above

# %% [markdown]
# ### STEP 2:
#     Check for the degrees of Freedom
#     which is 9 in this case and find the
#     intersect between column and row.
#     AS SHOWN ABOVE

# %% [markdown]
# ### SAMPLE TABLE:

# %%
Image('./Images/SGU6.png')

# %% [markdown]
# ### RESULTS:
# AS you can see as the sample size increses the interval decrese because:
#
# 1.Due to decrese in Standard Error as sample size grow up.
#
# 2.As sample increses the curve converge into Z distributon.

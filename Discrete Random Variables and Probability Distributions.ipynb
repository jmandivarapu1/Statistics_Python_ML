# %%
from IPython.display import Image
import os

# %%
#Ref:Applied Statistics and Probability for Engineers by Douglas C.Montgomery,George C.Runger
Image(os.path.join(os.getcwd(),'Discrete Random Variable and PD/Syallabus.jpg'))

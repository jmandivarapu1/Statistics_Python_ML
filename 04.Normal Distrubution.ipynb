# %%
from IPython.display import Image
Image('./Images/ND.png')

# %% [markdown]
# #Just imagine case of having dividing the area of 1
# #into 10 bars then probability if each bar is 1/10=0.1
# #into 100.....................................1/100=0.01
# #into 1000 .....................................1/1000=0.001
#
# This is the case but we now that incase of continous probability
# distrubution it can be infinite values so the probability
# is 1/n where is n is very large value so prbability will be
# a 0
# So only the above figure says the probabilty of any specific
# outcome iszero.
# we can only find the probability on specific interval only

# %%
Image('./Images/ND1.png')

# %%
Image('./Images/NDSP.png')

# %%
Image('./Images/NDSP1.png')

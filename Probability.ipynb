# %%
from IPython.display import Image
import os
os.getcwd()
# Out:
# '/Users/jmandivara/Documents/Statistics'

# %%
Will Discuss some of the concepts of the Probability in Detail

# %%
Image(os.path.join(os.getcwd(),'Images/Probability.jpg'))

# %% [markdown]
# ## Random Experiment?
# An experiment that can result in different outcomes, even though it is repeated in the same manner every time, is called a random experiment.
#
# Example:
# Measuring the current in a thin copper wire, we are conducting an experiment. However, day-to-day repetitions of the measurement can differ slightly because of small variations in variables that are not controlled in our experiment, including changes in ambient temperatures, slight variations in the gauge and small impurities in the chemical composition of the wire (if different locations are selected), and current source drifts. Consequently, this experiment (as well as many we conduct) is said to have a random component.

# %%
Image(os.path.join(os.getcwd(),'Images/Random.jpg'),height=50,width=300)

# %% [markdown]
# ## SAMPLE SPACES:
# WHY Sample Spaces:To model and analyze a random experiment, we must understand the set of possible outcomes from the experiment.
#
# The set of all possible outcomes of a random experiment is called the sample space of the experiment. The sample space is denoted as S.

# %% [raw]
# ## Types of Sample Space:
#     1.Discrete :A sample space is discrete if it consists of a  nite or countable in nite set of outcomes.
#         Eg:In below figure1.the choice S = R+ is an example of a continuous sample space, whereas S = {yes, no} is a discrete sample space
#     2.Continous:A sample space is continuous if it contains an interval (either  nite or in nite) of real numbers.

# %%
#figure 1: Continous Sample Space
#ref: https://www.youtube.com/watch?v=5Cc2-Pnq-U4
Image(os.path.join(os.getcwd(),'Images/COntinous_Sample_Space.jpg'),height=50,width=300)

# %%
#figure 2: Discrete Sample Space
Image(os.path.join(os.getcwd(),'Images/Discrete_Sample_Space.jpg'),height=50,width=300)

# %% [markdown]
# ## EVENTS Event

# %% [raw]
# An event is a subset of the sample space of a random experiment.

# %% [markdown]
# #### The union of two events is the event that consists of all out comes that are contained in either
# of the two events. We denote the union as E1 ∪ E2.
#
# The intersection of two events is the event that consists of all outcomes that are contained
# in both of the two events. We denote the intersection as E1 ∩ E2.
#
# The complement of an event in a samplespace is these to outcomes in the samplespace that are not in the event. We denote the complement of the event E as E′. The notation EC is also used in other literature to denote the complement.

# %% [markdown]
# ### COUNTING TECHNIQUES

# %% [markdown]
# #### Permutation and combinations---U can refer anything for this

# %% [markdown]
# ## 2-4 Conditional Probability

# %% [markdown]
# #### Sometimes probabilities need to be reevaluated as additional information becomes available
# A useful way to incorporate additional information into a probability model is to assume that the out- come that will be generated is a member of a given event.
#
# This event, say A, de nes the conditions that the outcome is known to satisfy. Then probabilities can be revised to include this knowledge.

# %% [markdown]
# #### Formula
# The probability of an event B under the knowledge that the outcome will be in event A is denoted as
# P(B|A) [ this is called the conditional probability of B given A.]

# %%
Image(os.path.join(os.getcwd(),'Images/COnditional_Probability.jpg'),height=50,width=600)

# %% [raw]
# ### Eg: If you have two children.One of them is boy what is the probability that other is a boy too
#
# Two ways you can solve this ...
# 1. No of ways :BG,GB,BB,GG
#                we need to eliminate the girl girl ---as it wont match of                  the given condition that one is a BOY
#    so answer is 1/3
#
# 2.Apply the given formula:
#    P(A ∩ B)/P(A)
#    Now take all the cases:BG,GB,BB,GG=P(A ∩ B)=1/4[Given other is a Boy]
#                           P(A)=probility of A which is given probability
#                                nothing but one should be a boy.
#                                3/4
#    so overall=1/4/3/4
#              =1/3

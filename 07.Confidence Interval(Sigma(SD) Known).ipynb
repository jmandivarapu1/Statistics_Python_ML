# %%
from IPython.display import Image
Image('./Images/CI1.png')

# %%
Image('./Images/CI2.png')

# %%
Image('./Images/CI3.png')

# %%
Image('./Images/CI4.png')

# %%
Image('./Images/CI5.png')

# %%
Image('./Images/CI7.png')

# %%
Image('./Images/CI8.png')

# %%
Image('./Images/CI9.png')

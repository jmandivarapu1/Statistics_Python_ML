# %% [markdown]
# #### Discrete Random Variable:
#     A voice communication system for a business contains 48 external lines. At a par-
#     ticular time, the system is observed, and some of the lines are being used. Let the random variable X denote the number of lines in use. Then X can assume any of the integer values 0 through 48. When the system is observed, if 10 lines are in use, x = 10.

# %% [markdown]
# #### Why:
#
# Random variables are so important in random experiments that sometimes we essentially ignore the original sample space of the experiment and focus on the probability distribution of the random variable. For example, in Example 3-1, our analysis might focus exclusively on the integers {0, 1, . . . , 48} in the range of X.

# %% [markdown]
# ### What is Probability Distribution?
#
# The probability distribution of a random variable X is a description of the probabilities associated with the possible values of X. For a discrete random variable, the distribution is often speci ed by just a list of the possible values along with the probability of each. In some cases, it is convenient to express the probability in terms of a formula.

# %%
from IPython.display import Image,HTML

# %%
import pandas as pd
from IPython.display import Image, HTML

df = pd.DataFrame(['<img src="./Images/Baye.jpg"/>', './Images/Baye.jpg'], columns = ['Image'])

HTML(df.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Image</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src="./Images/Baye.jpg"/></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>./Images/Baye.jpg</td>
#     </tr>
#   </tbody>
# </table>

# %%
import pandas as pd
from IPython.display import Image, HTML

df = pd.DataFrame(['./Images/Baye.jpg'],['./Images/Baye.jpg'], columns = ['Image'])

def path_to_image_html(path):
    return '<img src="'+ path + '"/>'

pd.set_option('display.max_colwidth', -1)

HTML(df.to_html(escape=False ,formatters=dict(Image=path_to_image_html)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Image</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>./Images/Baye.jpg</th>
#       <td><img src="./Images/Baye.jpg"/></td>
#     </tr>
#   </tbody>
# </table>

# %%
z=5
c=['<img src="./Images/Baye.jpg"/>',z,6]
df = pd.DataFrame({'a': c, 'b': [2,3,4]})
HTML(df.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src="./Images/Baye.jpg"/></td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>6</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>

# %%
DRV_Def='Definition'
DRV_Probability_Distributions='The probability distribution of a random variable X is a description of the probabilities associated with the possible values of X'
DRV_Probability_Mass_Functions='<img src="./Images/DRV_PMF.jpg"/>'
DRV_Cumulative_Distribution_Function='An alternate method for describing a random variable’s probability distribution is with cumu- lative probabilities such as P(X ≤ x). Furthermore, cumulative probabilities can be used to  nd the probability mass function of a discrete random variable. '
DRV_CDF_EG='<img src="./Images/DRV_CDF_EG.jpg"/>'
DRV_Mean='The mean is a measure of the center or middle of the probability distribution' + '<img src="./Images/DRV_Mean_SD_Var.jpg"/>'
DRV_Variance='variance is a measure of the dispersion, or variability in the distribution.'+ '<img src="./Images/DRV_Mean_SD_Var.jpg"/>'
DRV_Mean_Var='<img src="./Images/DRV_Mean_SD_Var.jpg"/>'
DRV_Distributions='Discrete Uniform Distribution,Binomial Distribution'

# %%
CRV_Def='Definition'
CRV_Probability_Distributions='PD'
CRV_Probability_Mass_Functions='PMF'
CRV_Mean='Mean'
CRV_Variance='Variance'
CRV_Distributions='Binominal'

# %%
a=[DRV_Def,DRV_Probability_Distributions,DRV_Probability_Mass_Functions,DRV_Cumulative_Distribution_Function,DRV_Mean,DRV_Variance,DRV_Distributions]
b=[DRV_Def,DRV_Probability_Distributions,DRV_Probability_Mass_Functions,DRV_Cumulative_Distribution_Function,DRV_Mean,DRV_Variance,DRV_Distributions]

df = pd.DataFrame({'Continuous Random Variables': b,'Discrete Random Variables': a})
HTML(df.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Continuous Random Variables</th>
#       <th>Discrete Random Variables</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Definition</td>
#       <td>Definition</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>The probability distribution of a random variable X is a description of the probabilities associated with the possible values of X</td>
#       <td>The probability distribution of a random variable X is a description of the probabilities associated with the possible values of X</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="./Images/DRV_PMF.jpg"/></td>
#       <td><img src="./Images/DRV_PMF.jpg"/></td>
#     </tr>
#     <tr>
#       <th>3</th>
# ...

# %%
from IPython.display import Image
import pydot
graph = pydot.Dot(graph_type='digraph')

node_a = pydot.Node("Distribution(for DRV)", shape="rectangle",style="filled")

node_b = pydot.Node("Binomial Distribution",shape="rectangle",style="", fillcolor="pink")
node_b1 = pydot.Node("Discrete Uniform Distribution", shape="rectangle",style="filled", fillcolor="pink")

node_c = pydot.Node("Geometric Distribution",shape="rectangle", style="filled", fillcolor="pink")
node_d = pydot.Node("Negative Binomial Dist", shape="rectangle",style="filled", fillcolor="pink")
node_e = pydot.Node("Hypergeometric Distribution",shape="rectangle", style="filled", fillcolor="pink")

graph.add_node(node_a)
graph.add_node(node_b)
graph.add_node(node_b1)
graph.add_node(node_c)
graph.add_node(node_d)
graph.add_node(node_e)


graph.add_edge(pydot.Edge(node_a, node_b,label="limited Trails"))
graph.add_edge(pydot.Edge(node_a, node_b1,label="limited Trails"))
graph.add_edge(pydot.Edge(node_a, node_c,label="Unlimited Trails"))
graph.add_edge(pydot.Edge(node_a, node_d,label="Unlimited Trails"))
graph.add_edge(pydot.Edge(node_a, node_e,label="Samples without Replacement"))

# and we are done
graph.write_png('example2_graph.png')
Image('example2_graph.png',width=10000)

# %% [markdown]
# ### Discrete Uniform Distribution
# The simplest discrete random variable is one that assumes only a  nite number of possible values, each with equal probability. A random variable X that assumes each of the values x1 , x2 , ... , xn with equal probability 1 / n is frequently of interest.

# %%
#Eg
Image('./Images/Discrete_Uniform_Distribution.jpg')

# %%
Image('./Images/Discrete_Uniform_Distribution_Mean.jpg')

# %% [markdown]
# ### Binomial Distribution

# %% [raw]
# 1.Flip a coin 10 times. Let X = number of heads obtained.
# 2. A worn machine tool produces 1% defective parts. Let X = number of defective parts in the next 25 parts produced.
# 3. Each sample of air has a 10% chance of containing a particular rare molecule. Let X = the number of air samples that contain the rare molecule in the next 18 samples analyzed.

# %% [raw]
# In above all the cases of the random experiment.A random experiment is
# repeated untill the output is achieved is sucess.
#
# In example 1 coin is flipped untill X(2) no of heads obtained.
#
#
# The outcome from each trial either meets the criterion that X counts or it does not; consequently, each
# trial can be summarized as resulting in either a success or a failure.
#
# For example, in the multiple-choice experiment, for each question,
# only the choice that is correct is considered a success.
# Choosing any one of the three incorrect choices results in the trial being summarized as a failure.
#
# similarly in the example 1 when you flip a coin 8 times and expecting it to
# have 6Heads if the ouput have it it is called Success or else Failure.

# %% [markdown]
# ### So............Finally...Bernoulli trial
# A trial with only two possible outcomes is used so frequently as a building block of a random experiment that it is called a Bernoulli trial.
#
# Assumptions:
# It is usually assumed that the trials that con- stitute the random experiment are independent.
#
# It is often rea- sonable to assume that the probability of a success in each trial is constant.(Selection From Multiple Choice)
#
#
# Eg: Coin Flip State above

# %%
Image('./Images/Binomial_Distribution.jpg')

# %%
#Eg:
Image('./Images/Binomial_Distribution_eg.jpg')

# %%
#More Examples
Image('./Images/Binomial_Distribution_eg1.jpg')

# %%
Image('./Images/Binomial_Dist_Mean.jpg')

# %% [markdown]
# ## Geometric Distribution

# %% [markdown]
# ###### Consider a random experiment that is closely related to the one used in the de nition of a binomial distribution. Again, assume a series of Bernoulli trials (independent trials with constant probability p of a success on each trial). However, instead of a  xed number of trials, trials are conducted until a success is obtained. Let the random variable X denote the
# Geometric and Negative Binomial Distributions
# number of trials until the  first success.
#
# Example:analyzed successive wafers until a large particle was detected.
#
# Example:Then X is the number of wafers analyzed. In the transmission of bits, X might be the number of bits transmitted until an error occurs.

# %%
    Image('./Images/Gd_mean.jpg')

# %%
Image('./Images/Gd_def.jpg')

# %% [markdown]
# ### Negative Binomial Distribution
# A generalization of a geometric distribution in which the random variable is the number of Bernoulli trials required to obtain r successes results in the negative binomial distribution.

# %%
Image('./Images/Negative_GM.jpg')

# %%
Image('./Images/NGD_mean.jpg')

# %% [markdown]
# #### Hypergeometric Distribution
#
# Sometimes in any random experiment. samples are often selected without replacement. Although prob- abilities can be determined by the preceding reasoning, a general formula for computing prob- abilities when samples are selected without replacement is quite useful.ant thus the Hypergeometric Distribution solves this problem

# %%
Image('./Images/Hyper_GD.jpg')

# %%
Image('./Images/Hyper_GD_mean.jpg')

# %%
#Example:
Image('./Images/Hyper_GM.jpg')

# %% [markdown]
# ### Poisson Distribution
# A widely-used distribution emerges from the concept that events occur randomly in an inter- val (or, more generally, in a region). The random variable of interest is the count of events that occur within the interval

# %%
#Example(IMP)
Image('./Images/Poison.jpg')

# %%
Image('./Images/Posion_Dist.jpg')

# %%
Image('./Images/Posion_mean.jpg')

# %%
Image('./Images/Posion_Eg.jpg')

# %% [markdown]
# # Continuous Random Variables and Probability Distributions

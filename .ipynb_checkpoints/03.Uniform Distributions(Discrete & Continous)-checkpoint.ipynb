# %% [markdown]
# ### Uniform Distributions gives you the idea of the curvers which is normal which will be discuss afterwards

# %%
from IPython.display import Image
Image('./Images/UniDPD.png')

# %%
why Uniform: All the outcomes gives same probability 1/2
why Discrete: can have only two outcome either he

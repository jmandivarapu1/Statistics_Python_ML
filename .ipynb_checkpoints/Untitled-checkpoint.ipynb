# %%
Random Variables help us 
 how to collect data,visualize data ..etc build distribution of data

# %%
Thought -1
If i roll a die what are possible outcomes you can get
-Exactly 1
-Excatly 2
-.....
-Exactly 6

only exactly 6 values but no middle values

# %%
Thought -2

If you want to measure avg family of state...?

It could be infinite possible values
Even though you the range also like 40,000.00 to 40,000.99
there will be infinetly possible values between them

we need a 1000 sided die to fit that.


Eventually ,the die surface would be almost continous just like cirlc

# %%
import os
from IPython.display import Image
Image(os.path.join(os.getcwd(),'Images/Random_Variable.png'))

# %%
Random variable must have numerical value.
denoted by X
outcomes as lower case letter x

# %%
X=throwing die
x=1,2,3,4,5,6

# %%
Image(os.path.join(os.getcwd(),'Images/DiscretsvsRandom.png'))

# %%
#Comment on above
In discrete "infinite seq of values " means you can have n no of values
theorotically
like eg: No of people standing in line in front of citi bank
    It can vary from anything to anything 0 to infinite theortically
    

Each is meanigfully different---means getting 1 is far more different than
getting 3 while throwing a die

# %%
#Comment on aboe Continues Random varailbe
diff btwn 40000 to 40000.01 is not meanigful
part of huge no of ouputs of average salary

# %%
Die throw is Discrete Random Variable
Continous Random Variable is average salary
